# %% [markdown]
# ## (Pre-Requisite) How to run MySQL in this toolkit

# %% [markdown]
# 1. This page will a Terminal instance and attempt to launch MySQL on the Virtual Machine with `sudo` permissions.

# %%
!(gnome-terminal -- sudo mysql)

# %% [markdown]
# > Not working? Open a Terminal instance by pressing `CTRL + ALT + T` on the Virtual Machine and run

# %% [markdown]
# 2. When the Terminal instance opens (shown below) enter `DLSU1234!` as the password.
#
#     ![image.png](attachment:image.png)

# %% [markdown]
# 3. Should you enter the the `sudo` password successfully, MySQL will run in that terminal instance and you will see info similar to the one shown below.
#     ![image.png](attachment:image.png)

# %% [markdown]
# 4. Note that closing this Terminal instance will stop MySQL from running. Keep MySQL open when in use.
